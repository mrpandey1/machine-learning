# %% [markdown]
# ## Introduction To Matplotlib

# %% [markdown]
# Its a Plotting library, It allows us to turn our data into pretty visualizations also known as plots or figures

# %% [markdown]
# ## Why matplotlib

# %% [markdown]
# Buit on NumPy arrays (and Python)
#
# Integrates directly with pandas
#
# Can create basic or advanced plots
#
# Simple to use interface (once you get the foundations)

# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
plt.plot()
# Out:
# []

# %%
plt.plot([1,2,3,4])#only does on X-axis

# %%
x=[1,2,3,4]
y=[10,20,30,40]
plt.plot(x,y) # on both X and y axis

# %%
fig=plt.figure()
ax=fig.add_subplot()
plt.show()

# %%
fig=plt.figure()
ax=fig.add_axes([1,1,1,1])
ax.plot(x,y)
plt.show()

# %%
fig,ax=plt.subplots()
ax.plot(x,y)

# %%
type(fig),type(ax)
# Out:
# (matplotlib.figure.Figure, matplotlib.axes._subplots.AxesSubplot)

# %% [markdown]
# ## Matplotlib Example workflow

# %%
#import matplotlib
import matplotlib.pyplot as plt

#prepare dataset
x=pd.Series([1,2,3,4])
y=pd.Series([10,20,30,40])

#setup plot
fig,ax=plt.subplots(figsize=(7,7))

#plot data
ax.plot(x,y)

#adding comments and title
ax.set(title='First Plot',xlabel='X-axis',ylabel='Y-axis')

#save the figure
fig.savefig('images/first_pot.png')

# %%
x=[1,2,3,4,5]
y=[50,60,10,80,77]

fig,ax=plt.subplots(figsize=(7,7))

ax.plot(x,y)

ax.set(title='sample_graph',
      xlabel='X-axis',
       ylabel='Y-axis')

fig.savefig('images/sample_plot2.png')

# %% [markdown]
# ## Making figures with NumPy arrays

# %% [markdown]
# - Line Plot
# - Scatter Plot
# - Bar Plot
# - Histogram
# - Sublots

# %% [markdown]
# ## Line Plot

# %%
x=np.linspace(0,10,100)

fig,ax=plt.subplots(figsize=(7,7))

ax.plot(x,x**2)

fig.savefig('images/Lineplot.png')

# %% [markdown]
# ## Scatter Plot

# %%
fig,ax=plt.subplots()
ax.scatter(x,np.exp(x))

fig.savefig('images/Scatterplot.png')

# %%
fig,ax=plt.subplots(figsize=(7,7))
ax.scatter(x,np.sin(x))

fig.savefig('images/Scatterplot2.png')

# %% [markdown]
# ## Bar Plot

# %%
prices={'mi a3':13000,'realme 6 pro':15000,'Moto e4 plus':10000}
fig,ax=plt.subplots(figsize=(7,7))
ax.bar(prices.keys(),prices.values(), color=(0.2, 0.4, 0.6, 0.6))
# Out:
# <BarContainer object of 3 artists>

# %%
shoe_number={'Nishant':11,'Prashant':10,'Ganesh':7,'Radha':6}
fig,ax=plt.subplots()
ax.bar(shoe_number.keys(),shoe_number.values())
# Out:
# <BarContainer object of 4 artists>

# %%
## horizontal bars
fig,ax=plt.subplots()
ax.barh(list(shoe_number.keys()),list(shoe_number.values()))
# Out:
# <BarContainer object of 4 artists>

# %% [markdown]
# ## Histogram

# %%
# Histogram
# creating random 1000 values for normal distribution
x = np.random.randn(1000)
fig,ax = plt.subplots()
ax.hist(x);

fig.savefig('images/his1.png')

# %% [markdown]
# ## Two options for subplot

# %%
## 1st option
import matplotlib.pyplot as plt
fig,((ax1,ax2),(ax3,ax4))=plt.subplots(nrows=2,ncols=2,figsize=(10,5))
ax1.plot(x,x/2)
ax2.scatter(np.random.random(10),np.random.random(10))
ax3.bar(shoe_number.keys(),shoe_number.values())
ax4.hist(np.random.randn(1000))
# Out:
# (array([  2.,  12.,  41.,  93., 236., 261., 227.,  95.,  28.,   5.]),
#  array([-3.58521302, -2.90825045, -2.23128788, -1.55432531, -0.87736274,
#         -0.20040017,  0.4765624 ,  1.15352497,  1.83048753,  2.5074501 ,
#          3.18441267]),
#  <a list of 10 Patch objects>)

# %%
# 2nd option
fig,ax=plt.subplots(ncols=2,nrows=2,figsize=(10,5))
ax[0,0].plot(x,x/2)
ax[0,1].scatter(np.random.random(10),np.random.random(10))
ax[1,0].bar(prices.keys(),prices.values())
ax[1,1].hist(np.random.randn(1000))
# Out:
# (array([  8.,  21.,  90., 174., 238., 228., 158.,  65.,  13.,   5.]),
#  array([-3.17692745, -2.5184307 , -1.85993395, -1.20143721, -0.54294046,
#          0.11555628,  0.77405303,  1.43254978,  2.09104652,  2.74954327,
#          3.40804002]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# ## Plotting from pandas DataFrame

# %%
import pandas as pd

# %%
car_sales=pd.read_csv('Datasets/car-sales.csv')
car_sales.head()
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00

# %%
ts=pd.Series(np.random.randn(1000),
          index=pd.date_range('1/1/2020',
        periods=1000))
ts=ts.cumsum()
ts
# Out:
# 2020-01-01     0.079579
# 2020-01-02    -3.293841
# 2020-01-03    -2.804080
# 2020-01-04    -1.398670
# 2020-01-05    -0.333317
#                 ...
# 2022-09-22    42.876569
# 2022-09-23    42.505676
# 2022-09-24    40.709244
# 2022-09-25    41.389369
# 2022-09-26    42.051964
# Freq: D, Length: 1000, dtype: float64

# %%
ts.plot()

# %%
car_sales.head()
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00

# %%
car_sales['Price'] = car_sales['Price'].str.replace('[\$\,\.]','')
car_sales['Price']=car_sales['Price'].str[:-2]

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price
# 0  Toyota  White         150043      4   4000
# 1   Honda    Red          87899      4   5000
# 2  Toyota   Blue          32549      3   7000
# 3     BMW  Black          11179      5  22000
# 4  Nissan  White         213095      4   3500
# 5  Toyota  Green          99213      4   4500
# 6   Honda   Blue          45698      4   7500
# 7   Honda   Blue          54738      4   7000
# 8  Toyota  White          60000      4   6250
# 9  Nissan  White          31600      4   9700

# %%
## adding sales date column
car_sales['Sales Date']=pd.date_range('1/1/2020',periods=
                                    len(car_sales))
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price Sales Date
# 0  Toyota  White         150043      4   4000 2020-01-01
# 1   Honda    Red          87899      4   5000 2020-01-02
# 2  Toyota   Blue          32549      3   7000 2020-01-03
# 3     BMW  Black          11179      5  22000 2020-01-04
# 4  Nissan  White         213095      4   3500 2020-01-05
# 5  Toyota  Green          99213      4   4500 2020-01-06
# 6   Honda   Blue          45698      4   7500 2020-01-07
# 7   Honda   Blue          54738      4   7000 2020-01-08
# 8  Toyota  White          60000      4   6250 2020-01-09
# 9  Nissan  White          31600      4   9700 2020-01-10

# %%
car_sales=car_sales.drop(['Total sum till date','Total'],axis=1)

# %%
car_sales['Total sum']=car_sales['Price'].astype(int).cumsum()
car_sales.head()
# Out:
#      Make Colour  Odometer (KM)  Doors  Price Sales Date  Total sum
# 0  Toyota  White         150043      4   4000 2020-01-01       4000
# 1   Honda    Red          87899      4   5000 2020-01-02       9000
# 2  Toyota   Blue          32549      3   7000 2020-01-03      16000
# 3     BMW  Black          11179      5  22000 2020-01-04      38000
# 4  Nissan  White         213095      4   3500 2020-01-05      41500

# %%
type(car_sales['Total sum'][0])
# Out:
# numpy.intc

# %%
car_sales.plot(x='Sales Date',y='Total sum');

# %%
car_sales['Price']=car_sales['Price'].astype(int)
car_sales.plot(x='Odometer (KM)',y='Price',kind='scatter')

# %%
car_sales.plot(x='Make',y='Price',kind='bar')

# %%
# creating bar graph using pandas Dataframe
np.random.seed(0)
x=np.random.randint(10,size=(10,4))
type(x)
# Out:
# numpy.ndarray

# %%
x
# Out:
# array([[5, 0, 3, 3],
#        [7, 9, 3, 5],
#        [2, 4, 7, 6],
#        [8, 8, 1, 6],
#        [7, 7, 8, 1],
#        [5, 9, 8, 9],
#        [4, 3, 0, 3],
#        [5, 0, 2, 3],
#        [8, 1, 3, 3],
#        [3, 7, 0, 1]])

# %%
# Turning into DataFrame
df=pd.DataFrame(x,columns=['a','b','c','d'])
df
# Out:
#    a  b  c  d
# 0  5  0  3  3
# 1  7  9  3  5
# 2  2  4  7  6
# 3  8  8  1  6
# 4  7  7  8  1
# 5  5  9  8  9
# 6  4  3  0  3
# 7  5  0  2  3
# 8  8  1  3  3
# 9  3  7  0  1

# %%
df.plot.bar()

# %%
df.plot(kind='bar')
